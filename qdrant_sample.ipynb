# %%
pip install qdrant_client
# Out:
# Collecting qdrant_client
#   Downloading qdrant_client-1.15.1-py3-none-any.whl.metadata (11 kB)
# Collecting grpcio>=1.41.0 (from qdrant_client)
#   Downloading grpcio-1.74.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting httpx>=0.20.0 (from httpx[http2]>=0.20.0->qdrant_client)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.26 in d:\e_folder\euron\first\.venv\lib\site-packages (from qdrant_client) (2.3.2)
# Collecting portalocker<4.0,>=2.7.0 (from qdrant_client)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting protobuf>=3.20.0 (from qdrant_client)
#   Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 (from qdrant_client)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: urllib3<3,>=1.26.14 in d:\e_folder\euron\first\.venv\lib\site-packages (from qdrant_client) (2.5.0)
# Requirement already satisfied: pywin32>=226 in d:\e_folder\euron\first\.venv\lib\site-packages (from portalocker<4.0,>=2.7.0->qdrant_client) (311)
# Collecting anyio (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client)
#   Using cached anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: certifi in d:\e_folder\euron\first\.venv\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (2025.8.3)
# Collecting httpcore==1.* (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in d:\e_folder\euron\first\.venv\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (3.10)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant_client)
#   Downloading h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client)
#   Using cached pydantic_core-2.33.2-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-extensions>=4.12.2 (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading qdrant_client-1.15.1-py3-none-any.whl (337 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading grpcio-1.74.0-cp312-cp312-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    -------------------------------- ------- 3.7/4.5 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 11.7 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading h2-4.2.0-py3-none-any.whl (60 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached anyio-4.10.0-py3-none-any.whl (107 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, protobuf, portalocker, hyperframe, hpack, h11, grpcio, annotated-types, typing-inspection, pydantic-core, httpcore, h2, anyio, pydantic, httpx, qdrant_client
#
#    ---- -----------------------------------  2/17 [protobuf]
#    ---- -----------------------------------  2/17 [protobuf]
#    ----------- ----------------------------  5/17 [hpack]
#    -------------- -------------------------  6/17 [h11]
#    ---------------- -----------------------  7/17 [grpcio]
#    ----------------------- ---------------- 10/17 [pydantic-core]
#    ------------------------- -------------- 11/17 [httpcore]
#    ------------------------------ --------- 13/17 [anyio]
#    ------------------------------ --------- 13/17 [anyio]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    -------------------------------- ------- 14/17 [pydantic]
#    ----------------------------------- ---- 15/17 [httpx]
#    ------------------------------------- -- 16/17 [qdrant_client]
#    ------------------------------------- -- 16/17 [qdrant_client]
#    ------------------------------------- -- 16/17 [qdrant_client]
#    ---------------------------------------- 17/17 [qdrant_client]
#
# Successfully installed annotated-types-0.7.0 anyio-4.10.0 grpcio-1.74.0 h11-0.16.0 h2-4.2.0 hpack-4.1.0 httpcore-1.0.9 httpx-0.28.1 hyperframe-6.1.0 portalocker-3.2.0 protobuf-6.32.0 pydantic-2.11.7 pydantic-core-2.33.2 qdrant_client-1.15.1 sniffio-1.3.1 typing-extensions-4.14.1 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from qdrant_client import QdrantClient

qdrant_client = QdrantClient(
    url="https://71db4fc0-98e9-40f8-89d4-6ab4b80be59a.us-east4-0.gcp.cloud.qdrant.io:6333", 
    api_key=os.getenv('Qdrant_api_key'),
)

print(qdrant_client.get_collections())
# Out:
# collections=[]

# %%
qdrant_client

# %%
collection_name = 'first_test'

# %%
from qdrant_client import models
qdrant_client.recreate_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(
        size=1536,distance=models.Distance.COSINE))
